# %% [markdown]
# # 此notebook用来下载虚拟货币数据，并作简单数据处理

# %% [markdown]
# ### 1. 导入必要的库

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))

from src.data_handler.raw_data_downloader import RawDataDownloader

# %% [markdown]
# ### 2. 下载虚拟货币数据

# %%
data_type = 'aggTrades' # 'aggTrades' or 'klines'
symbol = "BTCUSDT"
start_date = "2020-01-01"
end_date = "2025-12-31"
# inteval = "5m" # for klines
# base_dir = 'project_root/data/raw_data'

downloader = RawDataDownloader(data_type, symbol, start_date, end_date)
downloader.download()
# Out:
# 📥 下载数据: BTCUSDT klines (5m) | 2025-01-01 至 2025-12-31
# ----------------------------------------------------------------------
# 下载进度 |██████████| 365/365 [00:17<00:00]
# ----------------------------------------------------------------------
# ✅ 完成: 成功下载 365/365 天的数据
